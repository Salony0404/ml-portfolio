# %%
! pip install huggingface_hub

# %% [markdown]
# Day 1: Learning

# %%
from huggingface_hub import login 
from datasets import Dataset

# %%
login()

# %%
import pandas as pd 

data = pd.read_excel('code_new.xlsx')
data
# Out:
#                                               sentences  \
# 0     import requests\nimport re\n\ndef crawl_websit...
# 1                    [x*x for x in [1, 2, 3, 5, 8, 13]]
# 2     def remove_duplicates(string): \n    result = ...
# 3     def generate_random_divisible_number():\n    i...
# 4     def third_largest(lst):\n    if len(lst) < 3:\...
# ...                                                 ...
# 1897  import sqlite3\n\nconn = sqlite3.connect(':mem...
# 1898  import pandas as pd\nimport numpy as np\n\nimp...
# 1899  # Convert list of strings into a single string...
# 1900  def reverse_string(text): \n    # Convert stri...
# 1901  from sklearn.decomposition import PCA\npca = P...
#
#                                             Explanation
# 0     The provided Python script defines a function ...
# 1     The Python list comprehension [x*x for x in [1...
# 2     The provided Python function remove_duplicates...
# 3     The provided Python function generate_random_d...
# ...

# %%
data.isnull().sum()
# Out:
# sentences      4
# Explanation    7
# dtype: int64

# %%
# data = data.iloc[0:2499,0:2]
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# sentences      0
# Explanation    0
# dtype: int64

# %%
data.head()
# Out:
#                                            sentences  \
# 0  import requests\nimport re\n\ndef crawl_websit...
# 1                 [x*x for x in [1, 2, 3, 5, 8, 13]]
# 2  def remove_duplicates(string): \n    result = ...
# 3  def generate_random_divisible_number():\n    i...
# 4  def third_largest(lst):\n    if len(lst) < 3:\...
#
#                                          Explanation
# 0  The provided Python script defines a function ...
# 1  The Python list comprehension [x*x for x in [1...
# 2  The provided Python function remove_duplicates...
# 3  The provided Python function generate_random_d...
# 4  The provided Python function third_largest aim...

# %%
data.isnull().sum()
# Out:
# sentences        4
# Explanation    102
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# sentences      0
# Explanation    0
# dtype: int64

# %%
data
# Out:
#                                               sentences  \
# 0     import requests\nimport re\n\ndef crawl_websit...
# 1                    [x*x for x in [1, 2, 3, 5, 8, 13]]
# 2     def remove_duplicates(string): \n    result = ...
# 3     def generate_random_divisible_number():\n    i...
# 4     def third_largest(lst):\n    if len(lst) < 3:\...
# ...                                                 ...
# 1897  import sqlite3\n\nconn = sqlite3.connect(':mem...
# 1898  import pandas as pd\nimport numpy as np\n\nimp...
# 1899  # Convert list of strings into a single string...
# 1900  def reverse_string(text): \n    # Convert stri...
# 1901  from sklearn.decomposition import PCA\npca = P...
#
#                                             Explanation
# 0     The provided Python script defines a function ...
# 1     The Python list comprehension [x*x for x in [1...
# 2     The provided Python function remove_duplicates...
# 3     The provided Python function generate_random_d...
# ...

# %%
import pandas as pd

# Load the Excel files into Pandas DataFrames
file1 = pd.read_excel('linkss 1.xlsx')
file2 = pd.read_excel('code_new.xlsx')

# Merge the DataFrames
merged_data = pd.concat([file1, file2], ignore_index=True)

# Write the merged data to a new Excel file
data=merged_data.to_excel('code_file.xlsx', index=False)

# %%
# from datasets import load_dataset, concatenate_datasets

# # Load the existing dataset
# dataset = load_dataset('salony/code_explanations')

# # Load the new data (assuming it's also in the same format)
# new_data = load_dataset(dataset)

# # Concatenate the new data with the existing dataset
# updated_dataset = concatenate_datasets([dataset, new_data])

# # Save the updated dataset

# updated_dataset.push_to_hub("salony/code_explanations")

# %%
dataset = Dataset.from_pandas(file2)
dataset
# Out:
# Dataset({
#     features: ['sentences', 'Explanation'],
#     num_rows: 1902
# })

# %%
dataset=dataset.remove_columns(["__index_level_0__"])

# %%
dataset = dataset.train_test_split(test_size=0.2)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentences', 'Explanation'],
#         num_rows: 1521
#     })
#     test: Dataset({
#         features: ['sentences', 'Explanation'],
#         num_rows: 381
#     })
# })

# %%
dataset.push_to_hub("salony/code_explanations_2")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/salony/code_explanations/commit/fa80d9517bd2c139f830a6180544a885a42e43f6', commit_message='Upload dataset', commit_description='', oid='fa80d9517bd2c139f830a6180544a885a42e43f6', pr_url=None, pr_revision=None, pr_num=None)
